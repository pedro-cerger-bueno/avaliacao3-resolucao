# %% [markdown]
# **Resto de divisão: Caracterizado por sua simplicidade e alto nível de colisões. Usado para distribuição uniforme de elementos em uma tabela hash.**

# %% [markdown]
# **Multiplicação: Multiplica a chave e extrai parte do resultado. Diferentemente do hash por resto de divisão, essa técnica não é tão dependente no tamanho da tabela**

# %% [markdown]
# **Dobramento: Técnica em que a chave é dividida em duas partes menores que então são combinadas para formar o índice na tabela hash**

# %% [markdown]
# **TABELA 1000**

# %% [markdown]
# **Tabela 1000-Resto de divisão** <br>
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Tabela 1000-Multiplicação**
# <br>
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Tabela 1000-Dobramento** <br>
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Tabela 10000**

# %% [markdown]
# **Tabela 10000-Resto de divisão** <br>
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Tabela 10000-Multiplicação** <br>
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Tabela 10000-Dobramento**
# <br>
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **TABELA 100000**

# %% [markdown]
# **Tabela 100000-Resto de divisão** <br>
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Tabela 100000-Multiplicação** <br>
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Tabela 100000-Dobramento** <br>
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
